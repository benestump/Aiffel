# %% [markdown]
# ### PROJECT04 Flowers Classification

# %%
import tensorflow as tf 
import tensorflow_datasets as tfds 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

# %matplotlib inline
# %config inlineBackend.figure_format='retina'

# %%
# https://inpages.tistory.com/155
# 필요한 만큼 메모리를 런타임에 할당하는 방법(가장 처음 실행시켜 줄 것)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# #### 1. 데이터 불러오기
#  - tf_flowers의 80%는 train data, 10%는 validation data, 10%는 test data로 나눈다

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load('tf_flowers',
split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
with_info=True,
as_supervised=True,
)

# %%
plt.figure(figsize=(10, 5))

get_label_name = metadata.features['label'].int2str

for idx, (image, label) in enumerate(raw_train.take(10)):
    plt.subplot(2, 5, idx+1)
    plt.imshow(image)
    plt.title(f'label {label}: {get_label_name(label)}')
    plt.axis('off')

# %% [markdown]
# 이미지의 크기가 다양하다는 것을 확인할 수 있다.

# %%
IMG_SIZE = 160

def format_example(image, label):
    image = tf.cast(image, tf.float32)
    image = (image/127.5) - 1
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image, label

# %%
train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

# %%
plt.figure(figsize=(10, 5))

get_lable_name = metadata.features['label'].int2str

for idx, (image, label) in enumerate(train.take(10)):
    plt.subplot(2, 5, idx+1)
    image = (image+1) / 2
    plt.imshow(image)
    plt.title(f'label {label}:{get_label_name(label)}')
    plt.axis('off')

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

# %%
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %%
metadata
# Out:
# tfds.core.DatasetInfo(
#     name='tf_flowers',
#     version=3.0.1,
#     description='A large set of images of flowers',
#     homepage='https://www.tensorflow.org/tutorials/load_data/images',
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=5),
#     }),
#     total_num_examples=3670,
#     splits={
#         'train': 3670,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@ONLINE {tfflowers,
#     author = "The TensorFlow Team",
#     title = "Flowers",
#     month = "jan",
#     year = "2019",
#     url = "http://download.tensorflow.org/example_images/flower_photos.tgz" }""",
#     redistribution_info=,
# )

# %% [markdown]
# #### 2. 모델 학습
# #####  1) VGG16
#   1-1 Convolutional base는  ImageNet으로 학습된 파라미터를 그대로 사용하고 classifier만 새로 학습 시키는 방법

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %%
dense_layer = tf.keras.layers.Dense(512, activation='relu')
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([
    base_model, 
    global_average_layer,
    dense_layer,
    prediction_layer
])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Model)          (None, 5, 5, 1664)        12642880
# _________________________________________________________________
# global_average_pooling2d_8 ( (None, 1664)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               852480
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 2565
# =================================================================
# Total params: 13,497,925
# Trainable params: 855,045
# Non-trainable params: 12,642,880
# _________________________________________________________________

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
EPOCHS = 30   
history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/30
# 92/92 [==============================] - 7s 77ms/step - loss: 1.6092 - accuracy: 0.2507 - val_loss: 1.6088 - val_accuracy: 0.2425
# Epoch 2/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6087 - accuracy: 0.2517 - val_loss: 1.6082 - val_accuracy: 0.2425
# Epoch 3/30
# 92/92 [==============================] - 5s 59ms/step - loss: 1.6083 - accuracy: 0.2517 - val_loss: 1.6077 - val_accuracy: 0.2425
# Epoch 4/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6079 - accuracy: 0.2517 - val_loss: 1.6072 - val_accuracy: 0.2425
# Epoch 5/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6076 - accuracy: 0.2517 - val_loss: 1.6067 - val_accuracy: 0.2425
# Epoch 6/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6072 - accuracy: 0.2517 - val_loss: 1.6062 - val_accuracy: 0.2425
# Epoch 7/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6069 - accuracy: 0.2517 - val_loss: 1.6057 - val_accuracy: 0.2425
# Epoch 8/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6065 - accuracy: 0.2517 - val_loss: 1.6052 - val_accuracy: 0.2425
# Epoch 9/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6062 - accuracy: 0.2517 - val_loss: 1.6048 - val_accuracy: 0.2425
# Epoch 10/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6059 - accuracy: 0.2517 - val_loss: 1.6043 - val_accuracy: 0.2425
# Epoch 11/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6056 - accuracy: 0.2517 - val_loss: 1.6040 - val_accuracy: 0.2425
# Epoch 12/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6053 - accuracy: 0.2517 - val_loss: 1.6036 - val_accuracy: 0.2425
# Epoch 13/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6051 - accuracy: 0.2517 - val_loss: 1.6032 - val_accuracy: 0.2425
# Epoch 14/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6048 - accuracy: 0.2517 - val_loss: 1.6028 - val_accuracy: 0.2425
# Epoch 15/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6045 - accuracy: 0.2517 - val_loss: 1.6025 - val_accuracy: 0.2425
# Epoch 16/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6043 - accuracy: 0.2517 - val_loss: 1.6021 - val_accuracy: 0.2425
# Epoch 17/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6041 - accuracy: 0.2517 - val_loss: 1.6018 - val_accuracy: 0.2425
# Epoch 18/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6038 - accuracy: 0.2517 - val_loss: 1.6015 - val_accuracy: 0.2425
# Epoch 19/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6036 - accuracy: 0.2517 - val_loss: 1.6011 - val_accuracy: 0.2425
# Epoch 20/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6035 - accuracy: 0.2517 - val_loss: 1.6009 - val_accuracy: 0.2425
# Epoch 21/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6032 - accuracy: 0.2517 - val_loss: 1.6005 - val_accuracy: 0.2425
# Epoch 22/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6031 - accuracy: 0.2517 - val_loss: 1.6003 - val_accuracy: 0.2425
# Epoch 23/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6029 - accuracy: 0.2517 - val_loss: 1.6001 - val_accuracy: 0.2425
# Epoch 24/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6027 - accuracy: 0.2517 - val_loss: 1.5998 - val_accuracy: 0.2425
# Epoch 25/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6026 - accuracy: 0.2517 - val_loss: 1.5996 - val_accuracy: 0.2425
# Epoch 26/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6025 - accuracy: 0.2517 - val_loss: 1.5993 - val_accuracy: 0.2425
# Epoch 27/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6023 - accuracy: 0.2517 - val_loss: 1.5991 - val_accuracy: 0.2425
# Epoch 28/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6022 - accuracy: 0.2517 - val_loss: 1.5989 - val_accuracy: 0.2425
# Epoch 29/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6020 - accuracy: 0.2517 - val_loss: 1.5987 - val_accuracy: 0.2425
# Epoch 30/30
# 92/92 [==============================] - 5s 58ms/step - loss: 1.6019 - accuracy: 0.2517 - val_loss: 1.5985 - val_accuracy: 0.2425

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 위의 결과와 같이 상당히 나쁜 성능을 보여준다. base model을 학습시킨 데이터에는 daisy는 존재하였지만 다른 꽃의 종류는 존재하지 않아 학습이 되어 있지 않았다. 따라서 classifier만을 학습시키는 전략으로는 좋은 성능을 기대하기 어려웠다

# %% [markdown]
# - 동일한 모델을 처음부터 학습을 수행하여 보는 방법

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %%
dense_layer = tf.keras.layers.Dense(512, activation='relu')
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')

# %%
base_model.trainable = True #Convolutional base 부터 학습을 수행

# %%
model = tf.keras.Sequential([
    base_model, 
    global_average_layer,
    dense_layer,
    prediction_layer
])

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
EPOCHS = 30  
history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/30
# 92/92 [==============================] - 15s 164ms/step - loss: 1.5214 - accuracy: 0.3818 - val_loss: 0.9173 - val_accuracy: 0.6076
# Epoch 2/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.9350 - accuracy: 0.6543 - val_loss: 0.7622 - val_accuracy: 0.6594
# Epoch 3/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.6332 - accuracy: 0.7715 - val_loss: 0.6652 - val_accuracy: 0.7657
# Epoch 4/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.4969 - accuracy: 0.8253 - val_loss: 0.3556 - val_accuracy: 0.8638
# Epoch 5/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.4644 - accuracy: 0.8379 - val_loss: 0.3205 - val_accuracy: 0.8856
# Epoch 6/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3910 - accuracy: 0.8702 - val_loss: 0.4798 - val_accuracy: 0.8065
# Epoch 7/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3298 - accuracy: 0.8828 - val_loss: 0.3129 - val_accuracy: 0.8856
# Epoch 8/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3260 - accuracy: 0.8845 - val_loss: 0.3426 - val_accuracy: 0.8474
# Epoch 9/30
# 92/92 [==============================] - 15s 164ms/step - loss: 0.3288 - accuracy: 0.8910 - val_loss: 0.4505 - val_accuracy: 0.8392
# Epoch 10/30
# 92/92 [==============================] - 15s 164ms/step - loss: 0.2645 - accuracy: 0.9186 - val_loss: 7.8662 - val_accuracy: 0.6349
# Epoch 11/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2865 - accuracy: 0.9145 - val_loss: 0.7161 - val_accuracy: 0.7602
# Epoch 12/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2612 - accuracy: 0.9189 - val_loss: 0.2871 - val_accuracy: 0.8992
# Epoch 13/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2514 - accuracy: 0.9346 - val_loss: 0.3334 - val_accuracy: 0.8801
# Epoch 14/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3188 - accuracy: 0.9217 - val_loss: 0.4716 - val_accuracy: 0.8801
# Epoch 15/30
# 92/92 [==============================] - 15s 164ms/step - loss: 0.1835 - accuracy: 0.9421 - val_loss: 0.3088 - val_accuracy: 0.8992
# Epoch 16/30
# 92/92 [==============================] - 15s 164ms/step - loss: 0.2440 - accuracy: 0.9343 - val_loss: 0.3066 - val_accuracy: 0.9155
# Epoch 17/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2819 - accuracy: 0.9210 - val_loss: 0.3484 - val_accuracy: 0.9046
# Epoch 18/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2807 - accuracy: 0.9217 - val_loss: 2.3448 - val_accuracy: 0.7984
# Epoch 19/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3694 - accuracy: 0.9067 - val_loss: 0.5581 - val_accuracy: 0.8610
# Epoch 20/30
# 92/92 [==============================] - 15s 164ms/step - loss: 0.3705 - accuracy: 0.9118 - val_loss: 0.2800 - val_accuracy: 0.9074
# Epoch 21/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3411 - accuracy: 0.9166 - val_loss: 0.2790 - val_accuracy: 0.9019
# Epoch 22/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2264 - accuracy: 0.9377 - val_loss: 0.3619 - val_accuracy: 0.9074
# Epoch 23/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3840 - accuracy: 0.8999 - val_loss: 0.3377 - val_accuracy: 0.9183
# Epoch 24/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2931 - accuracy: 0.9326 - val_loss: 0.3426 - val_accuracy: 0.8992
# Epoch 25/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.4519 - accuracy: 0.9278 - val_loss: 0.4810 - val_accuracy: 0.8474
# Epoch 26/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3531 - accuracy: 0.9121 - val_loss: 0.5297 - val_accuracy: 0.8202
# Epoch 27/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.2791 - accuracy: 0.9285 - val_loss: 0.2577 - val_accuracy: 0.9019
# Epoch 28/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3650 - accuracy: 0.9257 - val_loss: 0.4423 - val_accuracy: 0.9155
# Epoch 29/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.3016 - accuracy: 0.9302 - val_loss: 0.4590 - val_accuracy: 0.9101
# Epoch 30/30
# 92/92 [==============================] - 15s 163ms/step - loss: 0.4790 - accuracy: 0.9234 - val_loss: 0.4901 - val_accuracy: 0.8828

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 처음부터 모델을 학습시키는 전략을 수행하였지만 이미지 데이터의 수(총 3670개, train data = 2936)가 너무 적어 제대로된 학습이 되지 않아 결과가 좋지 않았다.

# %% [markdown]
# - Convolutional base의 중간부터 학습하는 방법

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %%
dense_layer = tf.keras.layers.Dense(512, activation='relu')
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')

# %%
base_model.trainable = True

N_FREEZE = 10
for layer in base_model.layers[:N_FREEZE]:
    layer.trainable = False

# %%
model = tf.keras.Sequential([
    base_model, 
    global_average_layer,
    dense_layer,
    prediction_layer
])

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
EPOCHS = 30  
history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/30
# 92/92 [==============================] - 9s 99ms/step - loss: 0.9827 - accuracy: 0.6308 - val_loss: 0.6542 - val_accuracy: 0.7548
# Epoch 2/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4763 - accuracy: 0.8280 - val_loss: 0.3429 - val_accuracy: 0.8801
# Epoch 3/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3737 - accuracy: 0.8689 - val_loss: 0.4725 - val_accuracy: 0.8420
# Epoch 4/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3169 - accuracy: 0.8988 - val_loss: 0.2938 - val_accuracy: 0.8828
# Epoch 5/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.2731 - accuracy: 0.9196 - val_loss: 0.2744 - val_accuracy: 0.9155
# Epoch 6/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2125 - accuracy: 0.9315 - val_loss: 0.3701 - val_accuracy: 0.8965
# Epoch 7/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2032 - accuracy: 0.9384 - val_loss: 0.5073 - val_accuracy: 0.8556
# Epoch 8/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.2346 - accuracy: 0.9394 - val_loss: 0.3592 - val_accuracy: 0.9101
# Epoch 9/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2197 - accuracy: 0.9482 - val_loss: 0.4385 - val_accuracy: 0.8937
# Epoch 10/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.1963 - accuracy: 0.9418 - val_loss: 0.9331 - val_accuracy: 0.8965
# Epoch 11/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2245 - accuracy: 0.9472 - val_loss: 0.4961 - val_accuracy: 0.8501
# Epoch 12/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2592 - accuracy: 0.9363 - val_loss: 0.3298 - val_accuracy: 0.9101
# Epoch 13/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4333 - accuracy: 0.9234 - val_loss: 0.6375 - val_accuracy: 0.7766
# Epoch 14/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2409 - accuracy: 0.9394 - val_loss: 0.5318 - val_accuracy: 0.9155
# Epoch 15/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2108 - accuracy: 0.9520 - val_loss: 0.4752 - val_accuracy: 0.9101
# Epoch 16/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2730 - accuracy: 0.9319 - val_loss: 0.4588 - val_accuracy: 0.8910
# Epoch 17/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.1670 - accuracy: 0.9561 - val_loss: 0.5001 - val_accuracy: 0.9155
# Epoch 18/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2879 - accuracy: 0.9394 - val_loss: 0.4580 - val_accuracy: 0.8801
# Epoch 19/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3271 - accuracy: 0.9268 - val_loss: 0.5538 - val_accuracy: 0.9046
# Epoch 20/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4235 - accuracy: 0.9438 - val_loss: 0.3473 - val_accuracy: 0.9101
# Epoch 21/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3076 - accuracy: 0.9380 - val_loss: 0.5784 - val_accuracy: 0.9183
# Epoch 22/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3959 - accuracy: 0.9339 - val_loss: 0.5538 - val_accuracy: 0.8910
# Epoch 23/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3219 - accuracy: 0.9418 - val_loss: 0.6742 - val_accuracy: 0.8937
# Epoch 24/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2982 - accuracy: 0.9332 - val_loss: 0.4810 - val_accuracy: 0.8774
# Epoch 25/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.6830 - accuracy: 0.9384 - val_loss: 0.5186 - val_accuracy: 0.8910
# Epoch 26/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3172 - accuracy: 0.9445 - val_loss: 0.3652 - val_accuracy: 0.8747
# Epoch 27/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3844 - accuracy: 0.9411 - val_loss: 0.5868 - val_accuracy: 0.8420
# Epoch 28/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2221 - accuracy: 0.9489 - val_loss: 1.4460 - val_accuracy: 0.8883
# Epoch 29/30
# 92/92 [==============================] - 9s 97ms/step - loss: 0.9891 - accuracy: 0.9135 - val_loss: 0.6265 - val_accuracy: 0.8992
# Epoch 30/30
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3734 - accuracy: 0.9418 - val_loss: 0.7406 - val_accuracy: 0.9210

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# #### 2) DenseNet169

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
base_model = tf.keras.applications.DenseNet169(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
dense_layer = tf.keras.layers.Dense(512, activation='relu')
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')

base_model.trainable = False
    
model = tf.keras.Sequential([
base_model, 
global_average_layer,
dense_layer,
prediction_layer
])

base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
EPOCHS = 3 # epoch를 30을 하였을때 4부터 loss가 급격하게 증가하여 epoch를 3으로 수정
history = model.fit(train_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/3
# 92/92 [==============================] - 7s 79ms/step - loss: 0.1322 - accuracy: 0.9704 - val_loss: 0.2605 - val_accuracy: 0.9210
# Epoch 2/3
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.3134 - val_accuracy: 0.9264
# Epoch 3/3
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.3593 - val_accuracy: 0.9292

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 마지막 레이어에서 예측해야하는 클래스의 값을 실수로 2로 설정을 하여 여러가지 전략과 모델을 변경하여도 성능이 0.25에서 변화가 없었지만 이를 수정하니 전략에 따라 많은 차이가 생겼다
